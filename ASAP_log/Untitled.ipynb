# %%
import pickle as pk
import numpy as np
import pandas as pd

# %%
fo2 = open('../seq_acc-interf2-lv3.pk','rb')

# %%
acc = pk.load(fo2)

# %%
acc = np.array(acc)

# %%
acc = acc.reshape((5,10))

# %%
np.savetxt("acc.csv", acc, delimiter=",")

# %%
np.savetxt("logs1.csv",logs[0].T, delimiter =",")

# %%
np.savetxt("logs2.csv",logs[1].T, delimiter =",")

# %%
np.savetxt("logs3.csv",logs[2].T, delimiter =",")

# %%
np.savetxt("logs4.csv",logs[3].T, delimiter =",")

# %%
np.savetxt("logs5.csv",logs[4].T, delimiter =",")
