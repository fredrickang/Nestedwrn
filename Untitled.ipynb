# %%
import pickle as pk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
log_path = 'logs_test_01/test_01_error.csv'

data = pd.read_csv(log_path)
data
# Out:
#      Unnamed: 0   step  train_err1  train_err2  train_err3  val_err1  \
# 0             0    389    0.765625    0.835938    0.789062  0.920573
# 1             1    517    0.640625    0.671875    0.648438  0.851462
# 2             2    645    0.656250    0.664062    0.578125  0.815905
# 3             3    773    0.554688    0.492188    0.484375  0.815204
# 4             4    901    0.515625    0.468750    0.437500  0.687600
# 5             5   1029    0.554688    0.429688    0.390625  0.670673
# 6             6   1157    0.500000    0.460938    0.414062  0.652344
# 7             7   1285    0.468750    0.476562    0.445312  0.625801
# 8             8   1413    0.437500    0.429688    0.328125  0.614283
# 9             9   1541    0.460938    0.500000    0.398438  0.667869
# 10           10   1669    0.476562    0.468750    0.351562  0.597756
# 11           11   1797    0.398438    0.335938    0.250000  0.594451
# 12           12   1925    0.351562    0.312500    0.242188  0.577524
# ...

# %%
plt.figure()
data.plot(subplots=True , x='step', y='train_err1')
data.plot(subplots=True,  x='step', y='train_err2')
data.plot(subplots=True, x='step', y='train_err3')
plt.show()

# %%
plt.figure()
data.plot(subplots=True , x='step', y='val_err1')
data.plot(subplots=True,  x='step', y='val_err2')
data.plot(subplots=True, x='step', y='val_err3')
plt.show()
