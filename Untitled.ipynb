# %%
import numpy as np
import pickle as pk
import matplotlib.pyplot as plt

# %%
fo = open('seq_acc-lv3.pk','rb')
acc = pk.load(fo)
fo.close()

# %%
acc
# Out:
# [0.6637,
#  0.5965,
#  0.6363,
#  0.6642,
#  0.6321332353661523,
#  0.6493,
#  0.6396145610278373,
#  0.6483,
#  0.655,
#  0.6326804700615557]

# %%
np.mean(acc)
# Out:
# 0.6417728266455545

# %%
fo = open('logs.pk','rb')
logs = pk.load(fo)
fo.close()

# %%
plt.bar(logs[0][0],len(logs[0][0]))
# Out:
# <BarContainer object of 10000 artists>
