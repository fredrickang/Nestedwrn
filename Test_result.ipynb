# %%
import numpy as np
import pickle as pk
import os

# %%
acc_dir = 'test/acc2.pk'
time_dir = 'test/time.pk'

# %%
fo = open(acc_dir,'rb')
acc = pk.load(fo)
fo.close()

fo =open(time_dir,'rb')
time = pk.load(fo)
fo.close()

# %%
np.mean(time[1][1:])
# Out:
# 0.008691719596726212
