# %%
import numpy as np
import pickle as pk
import os

# %%
acc_dir = 'test2/lv3_acc.pk'
time_dir = 'test/time.pk'

# %%
fo = open(acc_dir,'rb')
acc = pk.load(fo)
fo.close()

fo =open(time_dir,'rb')
time = pk.load(fo)
fo.close()

# %%
np.max(time[1][1:])
# Out:
# 0.012668371200561523

# %%
np.max(time[3][1:])
# Out:
# 0.010982990264892578

# %%
np.max(time[5][1:])
# Out:
# 0.00870656967163086

# %%
acc
# Out:
# [0.7031, 0.6687, 0.625, 0.4641]
