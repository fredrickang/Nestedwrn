# %%
import numpy as np
import pickle as pk
import matplotlib.pyplot as plt

# %%
fo = open('1-1.pk','rb')
log_1_1 = pk.load(fo)
fo.close()
fo = open('1-125.pk','rb')
log_1_125 = pk.load(fo)
fo.close()
fo = open('3-1.pk','rb')
log_3_1 = pk.load(fo)
fo.close()
fo = open('3-125.pk','rb')
log_3_125 = pk.load(fo)
fo.close()

# %%
np.amax(log_1_1[0][1:])
# Out:
# 0.019234895706176758
