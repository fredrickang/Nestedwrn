# %%
import numpy as np
import pickle as pk
import matplotlib.pyplot as plt

# %%
fo = open('1-1.pk','rb')
log_1_1 = pk.load(fo)
fo.close()
fo = open('1-125.pk','rb')
log_1_125 = pk.load(fo)
fo.close()
fo = open('3-1.pk','rb')
log_3_1 = pk.load(fo)
fo.close()
fo = open('3-125.pk','rb')
log_3_125 = pk.load(fo)
fo.close()

# %%
1-np.mean(log_1_125[1])
# Out:
# 0.3456000089645386

# %%
1-np.mean(log_3_125[1])
# Out:
# 0.3776000142097473
